# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
matches.shape
# Out:
# (1389, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Brighton and Hove Albion    72
# Southampton                 72
# Tottenham Hotspur           71
# Manchester City             71
# Leeds United                71
# Wolverhampton Wanderers     71
# Arsenal                     71
# Crystal Palace              71
# Burnley                     71
# Chelsea                     70
# Aston Villa                 70
# Leicester City              70
# Everton                     70
# West Bromwich Albion        38
# Fulham                      38
# Liverpool                   38
# Sheffield United            38
# Brentford                   34
# Norwich City                33
# Watford                     33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
matches['round'].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 2     39
# Matchweek 3     39
# Matchweek 4     39
# Matchweek 5     39
# Matchweek 6     39
# Matchweek 7     39
# Matchweek 8     39
# Matchweek 9     39
# Matchweek 10    39
# Matchweek 11    39
# Matchweek 12    39
# Matchweek 13    39
# Matchweek 14    39
# Matchweek 15    39
# Matchweek 16    39
# Matchweek 17    39
# Matchweek 19    39
# Matchweek 20    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 34    39
# Matchweek 29    39
# Matchweek 31    39
# Matchweek 26    39
# Matchweek 28    39
# Matchweek 32    39
# Matchweek 18    37
# Matchweek 21    37
# Matchweek 22    37
# Matchweek 27    37
# Matchweek 30    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","", regex=True).astype(int)

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators= 1000, min_samples_split=15, random_state = 1)

# %%
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] > '2022-01-01']

# %%
predictor = ["venue_code","opp_code","hour","day_code"]

# %%
train.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'venue_code', 'opp_code', 'hour', 'day_code',
#        'target'],
#       dtype='object')

# %%
rf.fit(train[predictor],train["target"])
# Out:
# RandomForestClassifier(min_samples_split=15, n_estimators=1000, random_state=1)

# %%
preds = rf.predict(test[predictor])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.605072463768116

# %%
combined = pd.DataFrame(dict(actual = test["target"], predictions = preds))

# %%
combined
# Out:
#     actual  predictions
# 31       1            0
# 32       0            0
# 34       1            0
# 35       1            1
# 37       0            1
# ..     ...          ...
# 33       0            0
# 34       0            0
# 35       1            0
# 36       0            0
# 37       0            1
#
# [276 rows x 2 columns]

# %%
pd.crosstab(index = combined["actual"], columns = combined["predictions"])
# Out:
# predictions    0   1
# actual
# 0            145  27
# 1             82  22

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"],preds)
# Out:
# 0.4489795918367347

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester United")
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2021-08-14  12:30  Premier League   Matchweek 1  Sat  Home      W  5.0
# 1  2021-08-22  14:00  Premier League   Matchweek 2  Sun  Away      D  1.0
# 2  2021-08-29  16:30  Premier League   Matchweek 3  Sun  Away      W  1.0
# 3  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2021-09-19  14:00  Premier League   Matchweek 5  Sun  Away      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 55 2021-05-09  14:05  Premier League  Matchweek 35  Sun  Away      W  3.0
# 56 2021-05-11  18:00  Premier League  Matchweek 36  Tue  Home      L  1.0
# 57 2021-05-13  20:15  Premier League  Matchweek 34  Thu  Home      L  2.0
# 58 2021-05-18  18:00  Premier League  Matchweek 37  Tue  Home      D  1.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Away      W  2.0
#
#      ga        opponent  ...   fk   pk  pkatt  season               team  \
# ...

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("date")
  rolling_stats = group[cols].rolling(5, closed = 'left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset = new_cols)
  return group

# %%
cols = ["gf","ga","sh","sot","dist","fk","pk","pkatt"]
newcols = [f"{c}_rolling" for c in cols]

# %%
newcols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group,cols,newcols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 9  2020-11-01  16:30  Premier League   Matchweek 7  Sun  Home      L  0.0
# 11 2020-11-07  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 12 2020-11-21  20:00  Premier League   Matchweek 9  Sat  Home      W  1.0
# 14 2020-11-29  14:00  Premier League  Matchweek 10  Sun  Away      W  3.0
# 16 2020-12-05  17:30  Premier League  Matchweek 11  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 40 2022-04-02  17:30  Premier League  Matchweek 31  Sat  Home      D  1.0
# 41 2022-04-09  12:30  Premier League  Matchweek 32  Sat  Away      L  0.0
# 42 2022-04-16  15:00  Premier League  Matchweek 33  Sat  Home      W  3.0
# 43 2022-04-19  20:00  Premier League  Matchweek 30  Tue  Away      L  0.0
# 44 2022-04-23  12:30  Premier League  Matchweek 34  Sat  Away      L  1.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols,newcols), include_groups = True)
# Out:
# /tmp/ipython-input-1298858990.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols,newcols), include_groups = True)

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
#                         14 2020-11-22  16:30  Premier League   Matchweek 9
#                         16 2020-11-29  19:15  Premier League  Matchweek 10
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# 14 2020-11-22  16:30  Premier League   Matchweek 9  Sun  Away      D  0.0
# 16 2020-11-29  19:15  Premier League  Matchweek 10  Sun  Home      L  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data,predictor):
  train = data[data["date"] < '2022-01-01']
  test = data[data["date"] > '2022-01-01']
  rf.fit(train[predictor], train['target'])
  preds = rf.predict(test[predictor])
  combined = pd.DataFrame(dict(actual = test['target'], predictors = preds), index = test.index)
  precision = precision_score(test['target'],preds)
  return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictor + newcols)

# %%
precision
# Out:
# 0.5490196078431373

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 1    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 2    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# 3    2020-11-22  16:30  Premier League   Matchweek 9  Sun  Away      D  0.0
# 4    2020-11-29  19:15  Premier League  Matchweek 10  Sun  Home      L  1.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1264 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1265 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1266 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1267 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1268 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
combined = combined.merge(matches_rolling[["date", "team","opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predictors       date                     team       opponent  \
# 53         0           1 2022-01-23                  Arsenal        Burnley
# 54         1           1 2022-02-10                  Arsenal         Wolves
# 55         1           0 2022-02-19                  Arsenal      Brentford
# 56         1           1 2022-02-24                  Arsenal         Wolves
# 57         1           1 2022-03-06                  Arsenal        Watford
# ...      ...         ...        ...                      ...            ...
# 1264       1           0 2022-03-13  Wolverhampton Wanderers        Everton
# 1265       0           0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1266       1           0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1267       0           1 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1268       0           0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 53        D
# 54        W
# 55        W
# ...

# %%
class MissingDict(dict):
  __missing__ = lambda self, key : key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predictors       date                     team       opponent  \
# 53         0           1 2022-01-23                  Arsenal        Burnley
# 54         1           1 2022-02-10                  Arsenal         Wolves
# 55         1           0 2022-02-19                  Arsenal      Brentford
# 56         1           1 2022-02-24                  Arsenal         Wolves
# 57         1           1 2022-03-06                  Arsenal        Watford
# ...      ...         ...        ...                      ...            ...
# 1264       1           0 2022-03-13  Wolverhampton Wanderers        Everton
# 1265       0           0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1266       1           0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1267       0           1 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1268       0           0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new_team
# 53        D  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=["date","new_team"], right_on = ["date","opponent"])

# %%
merged
# Out:
#      actual_x  predictors_x       date                   team_x  \
# 0           0             1 2022-01-23                  Arsenal
# 1           1             1 2022-02-10                  Arsenal
# 2           1             0 2022-02-19                  Arsenal
# 3           1             1 2022-02-24                  Arsenal
# 4           1             1 2022-03-06                  Arsenal
# ..        ...           ...        ...                      ...
# 257         1             0 2022-03-13  Wolverhampton Wanderers
# 258         0             0 2022-03-18  Wolverhampton Wanderers
# 259         1             0 2022-04-02  Wolverhampton Wanderers
# 260         0             1 2022-04-08  Wolverhampton Wanderers
# 261         0             0 2022-04-24  Wolverhampton Wanderers
#
#         opponent_x result_x new_team_x  actual_y  predictors_y  \
# 0          Burnley        D    Arsenal         0             0
# 1           Wolves        W    Arsenal         0             0
# ...

# %%
merged[(merged["predictors_x"] == 1) &(merged['predictors_y'] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    25
# 0    19
# Name: count, dtype: int64

# %%
25/40 *100
# Out:
# 62.5
